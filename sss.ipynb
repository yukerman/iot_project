# %%
import pandas as pd


df = pd.read_csv(
    r'C:\Users\123\Documents\IoT_project\data\CTU-Honeypot-Capture-4-1\bro\conn.log.labeled',   
    sep="\t",                    # разделитель — табуляция
    comment="#",                 # строки с # будут пропущены как комментарии
    skipinitialspace=True,       # лишние пробелы после \t игнорировать
    skip_blank_lines=True        # пустые строки пропустить
)
df
# Out:
#      1540469302.538640  CGm6jB4dXK71ZDWUDh  192.168.1.132  58687  \
# 0         1.540469e+09  CnaDAG3n5r8eiG4su2  192.168.1.132   1900
# 1         1.540469e+09  CUrxU238nt0m6yTgKf  192.168.1.132  32893
# 2         1.540470e+09  CGQf8t1kjdxB5PHXL4  192.168.1.132  53395
# 3         1.540470e+09  CUo9DH2QDnCaBIGjkg  192.168.1.132  52801
# 4         1.540469e+09  CAvXOZ3htimWEtglii  192.168.1.132   1900
# ..                 ...                 ...            ...    ...
# 446       1.540547e+09  CaITg437HfJAXTXZ44  192.168.1.132  53722
# 447       1.540547e+09  ChD10Y1fVGrFvMpD6g  192.168.1.132  43799
# 448       1.540548e+09  Caxyou4MZpRXfDBG8h  192.168.1.132  51285
# 449       1.540469e+09   CkHQfG3B034MyvP3W  192.168.1.132  37653
# 450       1.540478e+09  ClZeN63S7LbgEs2ZNk  192.168.1.132   1900
#
#         216.239.35.4   123  udp    -      0.114184       48  ...   SF -.1 -.2  \
# 0    239.255.255.250  1900  udp    -    160.367579     7536  ...   S0   -   -
# ...
